# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Определение-наиболее-перспективной-(оценка-RICE)-гипотезы-для-увеличения-выручки-интернет-магазина-и-A/B-тестирование-гипотезы" data-toc-modified-id="Определение-наиболее-перспективной-(оценка-RICE)-гипотезы-для-увеличения-выручки-интернет-магазина-и-A/B-тестирование-гипотезы-1">Определение наиболее перспективной (оценка RICE) гипотезы для увеличения выручки интернет-магазина и A/B-тестирование гипотезы</a></span><ul class="toc-item"><li><span><a href="#Приоритизация-гипотез" data-toc-modified-id="Приоритизация-гипотез-1.1">Приоритизация гипотез</a></span><ul class="toc-item"><li><span><a href="#Фреймворк-ICE" data-toc-modified-id="Фреймворк-ICE-1.1.1">Фреймворк ICE</a></span></li><li><span><a href="#Фреймворк-RICE" data-toc-modified-id="Фреймворк-RICE-1.1.2">Фреймворк RICE</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.1.3">Выводы</a></span></li></ul></li><li><span><a href="#Расчет-показателей" data-toc-modified-id="Расчет-показателей-1.2">Расчет показателей</a></span><ul class="toc-item"><li><span><a href="#Общая-информация-о-группах-теста" data-toc-modified-id="Общая-информация-о-группах-теста-1.2.1">Общая информация о группах теста</a></span></li><li><span><a href="#График-кумулятивной-выручки-по-группам" data-toc-modified-id="График-кумулятивной-выручки-по-группам-1.2.2">График кумулятивной выручки по группам</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.2.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-1.2.3">График кумулятивного среднего чека по группам</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.3.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-1.2.4">График относительного изменения кумулятивного среднего чека группы B к группе A</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.4.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#График-кумулятивной-конверсии-по-группам" data-toc-modified-id="График-кумулятивной-конверсии-по-группам-1.2.5">График кумулятивной конверсии по группам</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.5.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A" data-toc-modified-id="График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A-1.2.6">График относительного изменения кумулятивной конверсии группы B к группе A</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.6.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#Точечный-график-количества-заказов-по-пользователям" data-toc-modified-id="Точечный-график-количества-заказов-по-пользователям-1.2.7">Точечный график количества заказов по пользователям</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.7.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#95-й-и-99-й-перцентили-количества-заказов-на-пользователя" data-toc-modified-id="95-й-и-99-й-перцентили-количества-заказов-на-пользователя-1.2.8">95-й и 99-й перцентили количества заказов на пользователя</a></span><ul class="toc-item"><li><span><a href="#Выбор-границы-для-определения-аномальных-пользователей" data-toc-modified-id="Выбор-границы-для-определения-аномальных-пользователей-1.2.8.1">Выбор границы для определения аномальных пользователей</a></span></li></ul></li><li><span><a href="#Точечный-график-стоимостей-заказов" data-toc-modified-id="Точечный-график-стоимостей-заказов-1.2.9">Точечный график стоимостей заказов</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.2.9.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#95-й-и-99-й-перцентили-стоимости-заказов" data-toc-modified-id="95-й-и-99-й-перцентили-стоимости-заказов-1.2.10">95-й и 99-й перцентили стоимости заказов</a></span><ul class="toc-item"><li><span><a href="#Выбор-границы-для-определения-аномальных-заказов" data-toc-modified-id="Выбор-границы-для-определения-аномальных-заказов-1.2.10.1">Выбор границы для определения аномальных заказов</a></span></li></ul></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-1.3">Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Различия-в-конверсии-между-группами-по-«сырым»-данным" data-toc-modified-id="Различия-в-конверсии-между-группами-по-«сырым»-данным-1.3.1">Различия в конверсии между группами по «сырым» данным</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.3.1.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#Различия-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Различия-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-1.3.2">Различия в среднем чеке заказа между группами по «сырым» данным</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.3.2.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#Различия-в-конверсии-между-группами-по-«очищенным»-данным" data-toc-modified-id="Различия-в-конверсии-между-группами-по-«очищенным»-данным-1.3.3">Различия в конверсии между группами по «очищенным» данным</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.3.3.1">Выводы и предположения</a></span></li></ul></li><li><span><a href="#Различия-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Различия-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-1.3.4">Различия в среднем чеке заказа между группами по «очищенным» данным</a></span><ul class="toc-item"><li><span><a href="#Выводы-и-предположения" data-toc-modified-id="Выводы-и-предположения-1.3.4.1">Выводы и предположения</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.4">Общий вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Определение наиболее перспективной (оценка RICE) гипотезы для увеличения выручки интернет-магазина и A/B-тестирование гипотезы

# %% [markdown]
# Совместно с отделом маркетинга интернет-магазина был подготовлен список гипотез для увеличения выручки.
#
# Необходимо:
# - приоритизировать гипотезы;
# - определить, есть ли значимые различия в показателях, влияющих на выручку, между группами A и B.

# %% [markdown]
# **Описание данных**
#
# - гипотезы по увеличению выручки интернет-магазина:
#     - `Hypothesis` — краткое описание гипотезы;
#     - `Reach` — охват пользователей по 10-балльной шкале;
#     - `Impact` — влияние на пользователей по 10-балльной шкале;
#     - `Confidence` — уверенность в гипотезе по 10-балльной шкале;
#     - `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
#
# - данные заказов:
#     - `transactionId` — идентификатор заказа;
#     - `visitorId` — идентификатор пользователя, совершившего заказ;
#     - `date` — дата, когда был совершён заказ;
#     - `revenue` — выручка заказа;
#     - `group` — группа A/B-теста, в которую попал заказ.
#
#
# - таблица с количеством посетителей в указанные даты:
#     - `date` — дата;
#     - `group` — группа A/B-теста;
#     - `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %%
# импортируем нужные библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
from IPython.display import display
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# устанавиваем параметры для лучшей читаемости
pd.options.display.max_colwidth = 120
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Приоритизация гипотез

# %% [markdown]
# В файле '/datasets/hypothesis.csv' гипотезы по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.

# %%
data = pd.read_csv('/datasets/hypothesis.csv') # запишем файл в переменную

# %%
data # визуально изучим файл
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# ### Фреймворк ICE

# %%
data['ICE'] = data['Impact'] * data['Confidence'] / data['Efforts']

# %%
data[['Hypothesis', 'ICE']].sort_values('ICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# ### Фреймворк RICE

# %%
data['RICE'] = (data['Reach'] * data['Impact'] * data['Confidence']) / data['Efforts']

# %%
data[['Hypothesis', 'RICE']].sort_values('RICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# Чтобы максимизировать ожидаемое улучшение ключевых метрик бизнеса, необходимо выбрать наиболее перспективные гипотезы. Согласно RICE, наибольший приоритет с отрывом по баллам от второго места в 2 раза имеет гипотеза №7:

# %%
data['Hypothesis'][7]
# Out:
# 'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок'

# %% [markdown]
# В обеих модификациях способов приоритизации среди пятерки гипотез-лидеров присутствуют 0, 7, 6, 2, 8, но гипотезы на разных местах, так как модификация RICE учитывает охват пользователей, а ICE - нет.
#
# Предпочтительнее ориентироваться на результаты RICE для выбора порядка проверки гипотез, так как важно учитывать, сколько пользователей затронет гипотеза.

# %% [markdown]
# ## Расчет показателей

# %% [markdown]
# Мы провели A/B-тест и получили результаты, которые описаны в файлах '/datasets/orders.csv' и '/datasets/visitors.csv'.
#
# Проведем предобработку данных.

# %%
# загрузим данные
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %%
def df_info(df): # функция для изучения содержимого датафреймов
    display(df.head())
    print('-*' * 25)
    df.info()
    print('-*' * 25)
    display(df.describe())

# %% [markdown]
# Данные о заказах:

# %%
df_info(orders)
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 37.5+ KB
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#          transactionId        visitorId      revenue
# ...

# %% [markdown]
# Данные о пользователях:

# %%
df_info(visitors)
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ KB
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#        visitors
# count     62.00
# mean     607.29
# std      114.40
# min      361.00
# 25%      534.00
# 50%      624.50
# 75%      710.50
# max      770.00

# %%
# преобразуем типы данных для дат и времени
orders['date'] = pd.to_datetime(orders['date'])
visitors['date'] = pd.to_datetime(visitors['date'])

# %%
df_info(visitors)
# Out:
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.3+ KB
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#        visitors
# count     62.00
# mean     607.29
# std      114.40
# min      361.00
# 25%      534.00
# 50%      624.50
# 75%      710.50
# max      770.00

# %%
# проверим данные на наличие дубликатов и пропусков
print(f'Дубликаты в orders: {orders.duplicated().sum()}. Пропуски в orders: {orders.isna().sum().sum()}.')
print(f'Дубликаты в visitors: {visitors.duplicated().sum()}. Пропуски в visitors: {visitors.isna().sum().sum()}.')
# Out:
# Дубликаты в orders: 0. Пропуски в orders: 0.
# Дубликаты в visitors: 0. Пропуски в visitors: 0.

# %% [markdown]
# Исходя из предварительной оценки датафреймов, можно сделать вывод, что данные качественные: они актуальны нашей задаче, не содержат явных ошибок или несоответствия форматов (кроме формата даты, на него в процессе предобработки мы поменяли формат соответствующей информации), визуальная оценка данных и результаты функции describe демонстрируют пригодность данных для анализа, большое количество записей и отсутствие в них пропусков и дубликатов.

# %% [markdown]
# ### Общая информация о группах теста

# %% [markdown]
# сколько у нас групп в АВ-тесте?

# %%
print('Количество групп в A/B-тесте:', len(visitors['group'].unique()))
# Out:
# Количество групп в A/B-тесте: 2

# %% [markdown]
# даты начала и окончания теста

# %%
print('Начало теста:', visitors['date'].min())
print('Окончание теста:', visitors['date'].max())
# Out:
# Начало теста: 2019-08-01 00:00:00
# Окончание теста: 2019-08-31 00:00:00

# %% [markdown]
# сколько пользователей в каждой группе - по таблице с заказами

# %%
print('Количество пользователей в группе A по таблице с заказами:', orders[orders['group'] == 'A']['visitorId'].nunique())
print('Количество пользователей в группе B по таблице с заказами:', orders[orders['group'] == 'B']['visitorId'].nunique())
# Out:
# Количество пользователей в группе A по таблице с заказами: 503
# Количество пользователей в группе B по таблице с заказами: 586

# %% [markdown]
# не попадают ли какие-то пользователи в обе группы - по таблице с заказами

# %%
buyers_A_id = orders[orders['group'] == 'A']['visitorId']
buyers_B_id = orders[orders['group'] == 'B']['visitorId']

# %%
intersection_users = pd.Series(list(set(buyers_A_id).intersection(set(buyers_B_id))))

# %%
print('В обе группы попадают', len(intersection_users), 'пользователей.')
# Out:
# В обе группы попадают 58 пользователей.

# %% [markdown]
# Удалим данные пользователей, попавших в обе группы:

# %%
orders = orders.query('visitorId not in @intersection_users')

# %% [markdown]
# ### График кумулятивной выручки по группам

# %%
# создадим массив уникальных пар значений дат и групп
dates_groups = orders[['date','group']].drop_duplicates()

# %%
orders_agg = dates_groups.apply(
    lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg(
        {
            'date' : 'max', 
            'group' : 'max', 
            'transactionId' : 'nunique', 
            'visitorId' : 'nunique', 
            'revenue' : 'sum'
        }
    ), axis=1
).sort_values(by=['date','group']) # кумулятивные данные по заказам

visitors_agg = dates_groups.apply(
    lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg(
        {
            'date' : 'max', 
            'group' : 'max', 
            'visitors' : 'sum'
        }
    ), axis=1
).sort_values(by=['date','group']) # кумулятивные данные по пользователям

# объединяем кумулятивные данные в одной таблице
cumulative_data = orders_agg.merge(visitors_agg, on=['date', 'group'], how='outer')
cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафреймы с кумулятивными данными по дням для групп A и B
cumulative_revenue_A = cumulative_data[cumulative_data['group']=='A'][['date','revenue', 'orders']]
cumulative_revenue_B = cumulative_data[cumulative_data['group']=='B'][['date','revenue', 'orders']]

# %%
# графики кумулятивной выручки
plt.figure(figsize=(10, 5))
plt.title(label='График кумулятивной выручки по группам')
plt.plot(cumulative_revenue_A['date'], cumulative_revenue_A['revenue'], label='A')
plt.plot(cumulative_revenue_B['date'], cumulative_revenue_B['revenue'], label='B')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Кумулятивная выручка', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Выручка увеличивается в течение всего теста, что является позитивным признаком - пользователи совершают новые и новые заказы.
#
# Однако графики выручки обеих групп в нескольких точках резко растут. Это может сигнализировать о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке.

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %%
plt.figure(figsize=(10, 5))
plt.title(label='График кумулятивного среднего чека по группам')
plt.plot(cumulative_revenue_A['date'], cumulative_revenue_A['revenue'] / cumulative_revenue_A['orders'], label='A')
plt.plot(cumulative_revenue_B['date'], cumulative_revenue_B['revenue'] / cumulative_revenue_B['orders'], label='B')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Кумулятивный средний чек', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Средний чек также подвержен скачкам и становится более равномерным ближе к концу теста: относительно стабилизируется для группы A и показывает тенденцию к снижению для группы B.
#
# Возможно, скачок графика для группы B в середине теста обусловлен крупным заказом, поэтому для группы B требуется больше данных, чтобы прийти к реальному среднему чеку и установиться на его уровне.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A

# %%
cumulative_revenue = cumulative_revenue_A.merge(cumulative_revenue_B, on='date', how='outer', suffixes=['_A', '_B'])
av_check_A = cumulative_revenue['revenue_A'] / cumulative_revenue['orders_A']
av_check_B = cumulative_revenue['revenue_B'] / cumulative_revenue['orders_B']

# %%
# отношение средних чеков
plt.figure(figsize=(10, 5))
plt.title(label='График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.plot(cumulative_revenue['date'], av_check_B / av_check_A - 1)
plt.axhline(y=0, color='black', linestyle='--') # ось на уровне 0
plt.grid()
plt.xticks(rotation=45)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Относительное изменение', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# В нескольких точках график относительного изменения кумулятивного среднего чека между группами резко «прыгает». Это сигнализирует о наличии крупных заказов и выбросов в данных. Отношение среднего чека между группами ещё не установилось.

# %% [markdown]
# ### График кумулятивной конверсии по группам

# %%
cumulative_data['conversion'] = cumulative_data['orders'] / cumulative_data['visitors'] # столбец с кумулятивной конверсией

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    cumulative_data[cumulative_data['group'] == 'A']['date'], \
    cumulative_data[cumulative_data['group'] == 'A']['conversion'], label='A'
)
plt.plot(
    cumulative_data[cumulative_data['group'] == 'B']['date'], \
    cumulative_data[cumulative_data['group'] == 'B']['conversion'], label='B'
)
plt.axis([cumulative_data['date'].min(), cumulative_data['date'].max(), 0, 0.05]) # задаем масштаб осей
plt.title(label='График кумулятивной конверсии по группам')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Кумулятивная конверсия', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Конверсия группы B в первые дни начала теста вышла вперёд и зафиксировалась на относительно постоянном уровне, конверсия группы A также зафиксировалась, но на более низких значениях.

# %% [markdown]
# ### График относительного изменения кумулятивной конверсии группы B к группе A

# %%
cumulative_data_A = cumulative_data[cumulative_data['group'] == 'A'] # отделяем данные для группы A
cumulative_data_B = cumulative_data[cumulative_data['group'] == 'B'] # отделяем данные для группы B

# %%
# таблица конверсией для двух групп по датам
conversion_groups = cumulative_data_A[['date', 'conversion']].merge( 
    cumulative_data_B[['date', 'conversion']], on='date', how='outer', suffixes=['_A', '_B']
)

# %%
plt.figure(figsize=(10, 5))
plt.title(label='График относительного изменения кумулятивной конверсии группы B к группе A')
plt.plot(conversion_groups['date'], conversion_groups['conversion_B'] / conversion_groups['conversion_A'] - 1)
plt.axhline(y=0, color='green', linestyle='--') # ось на уровне 0
plt.axhline(y=0.1, color='magenta', linestyle='--') # ось на уровне 0.1
plt.axis([cumulative_data['date'].min(), cumulative_data['date'].max(), -0.4, 0.4]) # задаем масштаб осей
plt.grid()
plt.xticks(rotation=45)
plt.xlabel('Дата', fontsize=12)
plt.ylabel('Относительное изменение', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Практически с первых дней теста группа B начала выигрывать у группы A в конверсии.
#
# Отношение конверсии ближе к концу теста установилось чуть выше отметки 0.1.
#
# Предварительно можно предположить, что конверсия группы B выше, нужен статистический анализ, чтобы подтвердить или опровергнуть предположение.

# %% [markdown]
# ### Точечный график количества заказов по пользователям

# %%
users_orders = orders.groupby('visitorId', as_index=False).agg({'transactionId': 'nunique'})
users_orders.columns = ['user_id', 'orders']

# %%
plt.figure(figsize=(10, 5))
plt.title(label='Точечный график количества заказов по пользователям')
plt.scatter(pd.Series(range(0, len(users_orders))), users_orders['orders'])
plt.xlabel('Пользователи', fontsize=12)
plt.ylabel('Количество заказов на пользователя', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Большинство покупателей заказывали только один раз. Однако доля пользователей с 2-3 заказами тоже значительна, но точно не ясна. Предварительно нельзя назвать аномальное количество заказов, необходима проверка на выбросы.

# %% [markdown]
# ### 95-й и 99-й перцентили количества заказов на пользователя

# %%
print(np.percentile(users_orders['orders'], [95, 99]))
# Out:
# [1. 2.]

# %% [markdown]
# #### Выбор границы для определения аномальных пользователей

# %% [markdown]
# Не более 5% пользователей оформляли больше чем 1 заказ и 1% пользователей заказывали более 2 раз.
#
# Так как 99% пользователей не оформляют более 2 заказов, выберем 2 заказа на одного пользователя как нижнюю границу для определения аномальных пользователей.

# %% [markdown]
# ### Точечный график стоимостей заказов

# %%
plt.figure(figsize=(10, 5))
plt.title(label='Точечный график стоимостей заказов')
plt.scatter(pd.Series(range(0, len(orders['revenue']))), orders['revenue'])
plt.xlabel('Заказы', fontsize=12)
plt.ylabel('Стоимость заказа', fontsize=12)
plt.show()

# %% [markdown]
# Из-за одного явного выброса все значения слились в одну прямую, нарисуем еще и график без него:

# %%
plt.figure(figsize=(10, 5))
plt.title(label='Точечный график стоимостей заказов')
without_anomaly = orders.query('revenue < 1000000')
plt.scatter(pd.Series(range(0, len(without_anomaly['revenue']))), without_anomaly['revenue'])
plt.xlabel('Заказы', fontsize=12)
plt.ylabel('Стоимость заказа', fontsize=12)
plt.show()

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# В данных, очевидно, есть заказы дороже 30 000, однако большинство из них на меньшую сумму. По графику сложно выбрать границу аномальных заказов, необходим расчет перцентилей.

# %% [markdown]
# ### 95-й и 99-й перцентили стоимости заказов

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# #### Выбор границы для определения аномальных заказов

# %% [markdown]
# Не более 5% заказов на сумму более 26 785, не более 1% - дороже 53 904.
#
# В качестве нижней границы для определения аномальных заказов выбираем 26 785 - 95% пользователей делали заказы, стоимость которых не превышала данную сумму.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Планируется протестировать 4 гипотезы, в связи с чем необходимо применить поправку на множественную проверку гипотез. Используем поправку Бонферрони. Принять альтернативную гипотезу, если:
#
#
# <center>$p ≥ \alpha / n, $</center>
#
#
# где $n$ — количество тестируемых гипотез.
#
# Применяем поправку для уровня значимости 0.05 и четырех гипотез:
#
# <center>0.05 / 4 = 0.0125</center>

# %% [markdown]
# ### Различия в конверсии между группами по «сырым» данным

# %% [markdown]
# ***H₀: различий в конверсии между группами A и B по «сырым» данным нет.***
#
# ***H₁: различия в конверсии между группами A и B по «сырым» данным есть.***
#
# Уровень статистической значимости α (с учетом поправки Бонферрони): 0.0125
#
# Метод проверки гипотез: U-критерий Манна-Уитни (выбросы сдвигают параметрические результаты, поэтому используем параметрический тест).

# %%
orders_A = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
) # таблица пользователь - количество заказов для группы A
orders_A.columns = ['user_id', 'orders']

orders_B = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
) # таблица пользователь - количество заказов для группы B
orders_B.columns = ['user_id', 'orders']

# %%
sample_A = pd.concat(
    [
        orders_A['orders'], pd.Series(0, index=np.arange(
            visitors[visitors['group'] == 'A']['visitors'].sum() - len(orders_A) # нули для не совершавших покупки
        ), name='orders')
    ], axis=0
).sort_values(ascending=False)

sample_B = pd.concat(
    [
        orders_B['orders'], pd.Series(0, index=np.arange(
            visitors[visitors['group'] == 'B']['visitors'].sum() - len(orders_B) # нули для не совершавших покупки
        ), name='orders')
    ], axis=0
).sort_values(ascending=False)

# %%
# проверим соответствие количества пользователей
print('Сумма длин списков "пользователь-количество заказов" групп A и B:', len(sample_A) + len(sample_B))
print('Сумма количества пользователей по данным датасета visitors:', visitors['visitors'].sum())
# Out:
# Сумма длин списков "пользователь-количество заказов" групп A и B: 37652
# Сумма количества пользователей по данным датасета visitors: 37652

# %%
print('p-value: {0:.3f}'.format(stats.mannwhitneyu(sample_A, sample_B)[1]))
print('Относительное различие между группами: {0:.2%}'.format(sample_B.mean() / sample_A.mean() - 1))
# Out:
# p-value: 0.006
# Относительное различие между группами: 15.98%

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Согласно «сырым» данным, различие в конверсии между группами A и B есть.
#
# p-value меньше 0.0125. Значит, нулевую гипотезу о том, что статистически значимых различий конверсии между группами нет, отвергаем.
#
# Относительный выигрыш группы B, согласно «сырым» данным, равен 15.98%.

# %% [markdown]
# ### Различия в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# ***H₀: различий в среднем чеке между группами A и B по «сырым» данным нет.***
#
# ***H₁: различия в среднем чеке между группами A и B по «сырым» данным есть.***
#
# Уровень статистической значимости α (с учетом поправки Бонферрони): 0.0125
#
# Метод проверки гипотез: U-критерий Манна-Уитни (выбросы сдвигают параметрические результаты, поэтому используем параметрический тест).

# %%
print('p-value: {0:.3f}'.format(
        stats.mannwhitneyu(orders[orders['group'] == 'A']['revenue'], orders[orders['group'] == 'B']['revenue'])[1]
    )
)
print('Относительное различие между группами: {0:.2%}'.format(
    orders[orders['group'] == 'B']['revenue'].mean() / orders[orders['group'] == 'A']['revenue'].mean() - 1)
)
# Out:
# p-value: 0.415
# Относительное различие между группами: 28.66%

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Согласно «сырым» данным, различия в среднем чеке между группами A и B нет.
#
# p-value намного больше 0.0125. Значит, нулевую гипотезу о том, что статистически значимых различий среднем чеке между группами нет, мы отвергнуть не можем, относительный выигрыш группы B статистически не значим.
#
# Мы видим, что относительное различие между группами велико, но статистически не значимо - это потому, что тест нечувствителен к выбросам.

# %% [markdown]
# ### Различия в конверсии между группами по «очищенным» данным

# %% [markdown]
# ***H₀: различий в конверсии между группами A и B по «очищенным» данным нет.***
#
# ***H₁: различия в конверсии между группами A и B по «очищенным» данным есть.***
#
# Уровень статистической значимости α (с учетом поправки Бонферрони): 0.0125
#
# Метод проверки гипотез: U-критерий Манна-Уитни (выбросы сдвигают параметрические результаты, поэтому используем параметрический тест).

# %%
many_orders = pd.concat(
    [
        orders_A[orders_A['orders'] > 2]['user_id'],
        orders_B[orders_B['orders'] > 2]['user_id'],
    ],
    axis=0,
) # пользователи с аномально большим количеством заказов

expensive_orders = orders[orders['revenue'] > np.percentile(orders['revenue'], 95)]['visitorId'] # пользователи, совершившие аномально дорогие заказы

abnormal_users = pd.concat([many_orders, expensive_orders], axis=0).drop_duplicates().sort_values() # единый список

# %%
print('Количество аномальных пользователей:', len(abnormal_users))
# Out:
# Количество аномальных пользователей: 58

# %%
filtered_sample_A = pd.concat(
    [
        orders_A[np.logical_not(orders_A['user_id'].isin(abnormal_users))]['orders'], pd.Series(0, index=np.arange(
            visitors[visitors['group'] == 'A']['visitors'].sum() - len(orders_A) # нули для не совершавших покупки
        ), name='orders')
    ], axis=0
)

filtered_sample_B = pd.concat(
    [
        orders_B[np.logical_not(orders_B['user_id'].isin(abnormal_users))]['orders'], pd.Series(0, index=np.arange(
            visitors[visitors['group'] == 'B']['visitors'].sum() - len(orders_B) # нули для не совершавших покупки
        ), name='orders')
    ], axis=0
)

# %%
print('p-value: {0:.3f}'.format(stats.mannwhitneyu(filtered_sample_A, filtered_sample_B)[1]))
print('Относительное различие между группами: {0:.2%}'.format(filtered_sample_B.mean() / filtered_sample_A.mean() - 1))
# Out:
# p-value: 0.006
# Относительное различие между группами: 18.19%

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Согласно «очищенным» данным, значимое различие в конверсии между группами A и B есть.
#
# Для «очищенных» данных p-value меньше 0.0125 - нулевую гипотезу о том, что статистически значимых различий конверсии между группами нет, отвергаем.
#
# Относительный выигрыш группы B, согласно «очищенным» данным, равен 18.19% - это на 2% больше, чем по «сырым» данным.

# %% [markdown]
# ### Различия в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# ***H₀: различий в среднем чеке между группами A и B по «очищенным» данным нет.***
#
# ***H₁: различия в среднем чеке между группами A и B по «очищенным» данным есть.***
#
# Уровень статистической значимости α (с учетом поправки Бонферрони): 0.0125
#
# Метод проверки гипотез: U-критерий Манна-Уитни (выбросы сдвигают параметрические результаты, поэтому используем параметрический тест).

# %%
print('p-value: {0:.3f}'.format(stats.mannwhitneyu(
    orders[np.logical_and(orders['group'] == 'A', np.logical_not(orders['visitorId'].isin(abnormal_users)))]['revenue'], \
    orders[np.logical_and(orders['group'] == 'B', np.logical_not(orders['visitorId'].isin(abnormal_users)))]['revenue'])[1])
)

print('Относительное различие между группами: {0:.2%}'.format(
    orders[
        np.logical_and(orders['group'] == 'B', np.logical_not(orders['visitorId'].isin(abnormal_users)))
    ]['revenue'].mean() / 
    orders[
        np.logical_and(orders['group'] == 'A', np.logical_not(orders['visitorId'].isin(abnormal_users)))
    ]['revenue'].mean() - 1)
)
# Out:
# p-value: 0.323
# Относительное различие между группами: -4.85%

# %% [markdown]
# #### Выводы и предположения

# %% [markdown]
# Согласно «очищенным» от выбросов данным, различия в среднем чеке между группами A и B нет.
#
# p-value намного больше 0.0125, как и для «сырых» данных. Значит, нулевую гипотезу о том, что статистически значимых различий среднем чеке между группами нет, мы отвергнуть не можем.
#
# Относительное различие между группами после удаления выбросов данных упало с почти 28.66% до -4.85%. Разницы в среднем чеке между группами нет, на предыдущие результаты влияли аномальные значения.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Чтобы максимизировать улучшение ключевых метрик бизнеса, необходимо выбрать наиболее перспективные гипотезы. Согласно оценке RICE, наибольший приоритет из всех представленных имеет идея *'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок'*. Проведен A/B-тест, группа A - контрольная, группа B - экспериментальная, для участников группы B на всех основных страницах отображалась форма подписки.
#
# _Выявлено статистически значимое различие по **конверсии** между группами_ как по «сырым» данным, так и по данным после фильтрации аномалий. Согласно очищенным от аномалий данным, разница в конверсии составила 17% в пользу группы B.
#
# Как по «сырым» данным, так и по данным после удаления аномалий, _статистически значимого различия по **среднему чеку** между группами обнаружено не было_.
#
# Таким образом, **группа B «выиграла» по показателю конверсии в покупку**. Добавление формы подписки на все основные страницы для сбора базы клиентов будет способствовать увеличению выручки за счет роста конверсии.
